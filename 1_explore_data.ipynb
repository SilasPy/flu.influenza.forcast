# %%
import pandas as pd
import numpy as np
import os

cwd = os.getcwd()
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
print("Pandas package:", pd.__package__)
cwd
datafile = r"c://Users//resha//Downloads//my work//flucast//data//flucastinfo//FluView_StackedColumnChart_Data.csv"
df = pd.read_csv(datafile)
df.head()
# Out:
# Pandas version: 3.0.3
# NumPy version: 2.5.1
# Pandas package: pandas
#    YEAR  WEEK  TOTAL SPECIMENS  TOTAL A  TOTAL B  PERCENT POSITIVE  PERCENT A  \
# 0  2025    40            55704      243       46          0.518814   0.436234
# 1  2025    41            57037      257       44          0.527728   0.450585
# 2  2025    42            55540      307       51          0.644580   0.552755
# 3  2025    43            56782      399       47          0.785460   0.702687
# 4  2025    44            56102      552       62          1.094440   0.983922
#
#    PERCENT B
# 0   0.082579
# 1   0.077143
# 2   0.091826
# 3   0.082773
# 4   0.110513
